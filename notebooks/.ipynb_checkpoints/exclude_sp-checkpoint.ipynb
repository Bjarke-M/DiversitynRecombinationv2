# %%
import pandas as pd

# %%
df = pd.read_csv('../data/science.abn7829_data_s1.csv',sep=',')

# %%
df
# Out:
#           PDGP_ID       GENUS      SPECIES SUBSPECIES          FAMILY  \
# 0         PD_0001  Cheracebus       lugens        ssp     Pitheciidae
# 1         PD_0002  Callibella      humilis        ssp  Callitrichidae
# 2         PD_0003     Cacajao       hosomi        ssp     Pitheciidae
# 3         PD_0004      Ateles    belzebuth        ssp        Atelidae
# 4         PD_0005    Alouatta  macconnelli        ssp        Atelidae
# ..            ...         ...          ...        ...             ...
# 804  SAMN01920547       Pongo     pygmaeus        ssp       Hominidae
# 805  SAMN01920548       Pongo     pygmaeus        ssp       Hominidae
# 806  SAMN01920549       Pongo     pygmaeus        ssp       Hominidae
# 807  SAMN01920550       Pongo     pygmaeus        ssp       Hominidae
# 808  SAMN01920551       Pongo     pygmaeus        ssp       Hominidae
#
#     GEOGRAPHIC_REGION                   COMMON_NAME IUCN_STATUS  \
# ...

# %%
failed_df = df[(df["COV_QC"] == 'FAIL') | (df["AB_QC"] == 'FAIL')]

# %%
failed_df[failed_df['PDGP_ID','GENUS','SPECIES','REFERENCE_SPECIES']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/bircproject/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('PDGP_ID', 'GENUS', 'SPECIES', 'REFERENCE_SPECIES')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ...
